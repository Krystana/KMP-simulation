# %%
import pandas as pd 
import numpy as np

# %%
transition_matrix = transition_matrix = pd.read_csv("./trans_matrix_prob.csv")
transition_matrix.set_index('location', inplace = True)
#transition_matrix.drop('Unnamed: 0', axis=1, inplace=True)
print(transition_matrix)
# Out:
#           checkout     dairy    drinks     fruit    spices
# location
# checkout  0.362546  0.165161  0.153296  0.175408  0.143589
# dairy     0.265284  0.201368  0.157546  0.225524  0.150278
# drinks    0.299616  0.190525  0.160819  0.200256  0.148784
# fruit     0.246974  0.203827  0.157165  0.229793  0.162241
# spices    0.280234  0.192861  0.159297  0.214971  0.152637

# %%
# check the matrix sum(sum each row) == 5 ---> ok!
sum(transition_matrix.sum(axis=1))
# Out:
# 4.999999999999999

# %%
# to select row of transition matrix: transition_matrix.iloc[i,:]
transition_matrix.iloc[0,:]
# Out:
# checkout    0.362546
# dairy       0.165161
# drinks      0.153296
# fruit       0.175408
# spices      0.143589
# Name: checkout, dtype: float64

# %%
# define state
#state = ['checkout', 'dairy', 'drinks', 'fruit', 'spices']

# %%
# define transition name: possible sequence of events
#transition_name = [['CkCk', 'CkDa', 'CkDr', 'CkFr', 'CkSp' ],
                  # ['DaCk', 'DaDa', 'DaDr', 'DaFr', 'DaSp' ],
                   #['DrCk', 'DrDa', 'DrDr', 'DrFr', 'DrSp' ],
                 #  ['FrCk', 'FrDa', 'FrDr', 'FrFr', 'FrSp' ],
                  # ['SpCk', 'SpDa', 'SpDr', 'SpFr', 'SpSp' ]]

# %%
import numpy as np



class Customer:
    """Customer class for Supermarket simulation"""
    
    def __init__(self, customer_no, state, transition_matrix):
        self.customer_no = customer_no
        self.state = state
        self.transition_matrix = transition_matrix    # transition matrix
        
        
    def __repr__(self):
        return f'Customer {self.customer_no} is in the {self.state} section'
         
   
    
    
    
    def change_state(self):
            
            #print(self.state)
            print('change_state')
               
            self.state = np.random.choice(self.transition_matrix.columns.values, p=self.transition_matrix.loc[self.state]) #, replace=False)
            
   # random.choices

# %% [markdown]
# ## simulation for 1 customer

# %%
c1 = Customer(1, 'drinks', transition_matrix)

# %%
c1.state
# Out:
# 'drinks'

# %%
c1.change_state()
# Out:
# change_state

# %%
c1.state
# Out:
# 'dairy'

# %%
customers = [Customer(i, 'fruit',transition_matrix) for i in range(10)]

# %%
for i, c in enumerate(customers): #at each minute, move all customers
    c.change_state()
    if c.state == 'checkout':
        print(f'Customer {i} has been churned!')
# Out:
# change_state
# change_state
# Customer 1 has been churned!
# change_state
# change_state
# Customer 3 has been churned!
# change_state
# change_state
# change_state
# change_state
# Customer 7 has been churned!
# change_state
# Customer 8 has been churned!
# change_state

# %%
customers
# Out:
# [Customer 0 is in the dairy section,
#  Customer 1 is in the checkout section,
#  Customer 2 is in the fruit section,
#  Customer 3 is in the checkout section,
#  Customer 4 is in the drinks section,
#  Customer 5 is in the spices section,
#  Customer 6 is in the dairy section,
#  Customer 7 is in the checkout section,
#  Customer 8 is in the checkout section,
#  Customer 9 is in the fruit section]

# %% [markdown]
# ## create class Supermarket

# %%
import time
import datetime
from faker import Faker



fake = Faker()
open_supermarket = datetime.datetime(year= 2021, month=1, day=1,hour=7, minute=0)
close_supermarket = datetime.datetime(year= 2021, month=1, day=1,hour=21, minute=0)


class Supermarket:
    """manages multiple Customer instances that are currently in the market.
 """

    def __init__(self, customers): 
        self.customers = customers
        self.current_time = 0 
        

    def get_time(self):  #open supermarket
        """opening hour
        """
  
        
        self.current_time = open_supermarket  # opening hour
      
        return self.current_time
    
    def next_minute(self):
        """propagates all customers to the next state 
        w/ change_state
     """
        self.current_time = self.current_time + datetime.timedelta(minutes=1)
     
        
        for element in self.customers:
            element.change_state()
            
        return self.current_time   #?
    
    
    
    def remove_ex_customers(self):
        """remove churned from list"""
        
        for element in self.customers:
            if element.state == 'checkout':
                self.customers.remove(element)
                print(f'{element} is removed')
    
 
    def simulate(self):
        
   
        self.get_time()
        self.next_minute()
        
        
        while self.current_time > open_supermarket: 
                
                
                self.next_minute()
                self.remove_ex_customers()
                
                c = Customer(fake.name(), 'drinks', transition_matrix)
          
                self.customers.append(c)    # append more customers?
                   
                if self.current_time > close_supermarket:
                    
                    break

# %%
#import time
#import datetime
#open_supermarket = datetime.datetime(year= 2021, month=1, day=1,hour=7, minute=0)
#current_time = open_supermarket 
#current_time = current_time + datetime.timedelta(minutes=1)

# %%
#current_time > open_supermarket

# %%
customers = [Customer(i, 'fruit',transition_matrix) for i in range(100)]

# %%
s = Supermarket(customers)

# %%
s.simulate()
# Out:
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 0 is in the checkout section is removed
# Customer 5 is in the checkout section is removed
# Customer 9 is in the checkout section is removed
# Customer 12 is in the checkout section is removed
# Customer 19 is in the checkout section is removed
# Customer 21 is in the checkout section is removed
# Customer 35 is in the checkout section is removed
# Customer 41 is in the checkout section is removed
# Customer 44 is in the checkout section is removed
# Customer 52 is in the checkout section is removed
# Customer 54 is in the checkout section is removed
# Customer 56 is in the checkout section is removed
# Customer 65 is in the checkout section is removed
# Customer 67 is in the checkout section is removed
# Customer 70 is in the checkout section is removed
# Customer 72 is in the checkout section is removed
# Customer 82 is in the checkout section is removed
# Customer 89 is in the checkout section is removed
# Customer 94 is in the checkout section is removed
# Customer 96 is in the checkout section is removed
# Customer 98 is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 8 is in the checkout section is removed
# Customer 20 is in the checkout section is removed
# Customer 23 is in the checkout section is removed
# Customer 25 is in the checkout section is removed
# Customer 27 is in the checkout section is removed
# Customer 29 is in the checkout section is removed
# Customer 31 is in the checkout section is removed
# Customer 33 is in the checkout section is removed
# Customer 39 is in the checkout section is removed
# Customer 43 is in the checkout section is removed
# Customer 59 is in the checkout section is removed
# Customer 64 is in the checkout section is removed
# Customer 68 is in the checkout section is removed
# Customer 74 is in the checkout section is removed
# Customer 76 is in the checkout section is removed
# Customer 78 is in the checkout section is removed
# Customer 83 is in the checkout section is removed
# Customer 86 is in the checkout section is removed
# Customer 91 is in the checkout section is removed
# Customer 99 is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 1 is in the checkout section is removed
# Customer 11 is in the checkout section is removed
# Customer 17 is in the checkout section is removed
# Customer 30 is in the checkout section is removed
# Customer 36 is in the checkout section is removed
# Customer 45 is in the checkout section is removed
# Customer 47 is in the checkout section is removed
# Customer 49 is in the checkout section is removed
# Customer 53 is in the checkout section is removed
# Customer 63 is in the checkout section is removed
# Customer 81 is in the checkout section is removed
# Customer 93 is in the checkout section is removed
# Customer Tammy Jackson MD is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 2 is in the checkout section is removed
# Customer 13 is in the checkout section is removed
# Customer 15 is in the checkout section is removed
# Customer 22 is in the checkout section is removed
# Customer 32 is in the checkout section is removed
# Customer 40 is in the checkout section is removed
# Customer 51 is in the checkout section is removed
# Customer 58 is in the checkout section is removed
# Customer 73 is in the checkout section is removed
# Customer 79 is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 3 is in the checkout section is removed
# Customer 14 is in the checkout section is removed
# Customer 18 is in the checkout section is removed
# Customer 26 is in the checkout section is removed
# Customer 55 is in the checkout section is removed
# Customer 75 is in the checkout section is removed
# Customer 87 is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 4 is in the checkout section is removed
# Customer 16 is in the checkout section is removed
# Customer 28 is in the checkout section is removed
# Customer 42 is in the checkout section is removed
# Customer 48 is in the checkout section is removed
# Customer 71 is in the checkout section is removed
# Customer 90 is in the checkout section is removed
# Customer 95 is in the checkout section is removed
# Customer Mr. Logan Case is in the checkout section is removed
# Customer Joshua West is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 7 is in the checkout section is removed
# Customer 66 is in the checkout section is removed
# Customer Steven Sanchez is in the checkout section is removed
# Customer Jonathon Roberts is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 24 is in the checkout section is removed
# Customer 37 is in the checkout section is removed
# Customer 50 is in the checkout section is removed
# Customer 61 is in the checkout section is removed
# Customer 77 is in the checkout section is removed
# Customer 92 is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 34 is in the checkout section is removed
# Customer 57 is in the checkout section is removed
# Customer 88 is in the checkout section is removed
# Customer Brandon Hickman is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 10 is in the checkout section is removed
# Customer 62 is in the checkout section is removed
# Customer Lee Campos is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 69 is in the checkout section is removed
# Customer Felicia Stewart is in the checkout section is removed
# Customer Laura Garza is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 60 is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 6 is in the checkout section is removed
# Customer 85 is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 38 is in the checkout section is removed
# Customer 80 is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 46 is in the checkout section is removed
# Customer 97 is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer 84 is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jennifer Grant is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Joel Vaughn is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Angela Simon is in the checkout section is removed
# Customer Erica Jackson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Ann Henderson is in the checkout section is removed
# Customer Eric Hansen is in the checkout section is removed
# Customer Angela Bates is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer John Thompson is in the checkout section is removed
# Customer Henry Lewis is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Matthew Klein is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Emily Cummings is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Matthew Parker is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Riley Stuart is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Emily Lopez is in the checkout section is removed
# Customer Erin Hancock is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Emily Villanueva is in the checkout section is removed
# Customer Melissa Holmes is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Angela Blackburn is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Jacob Conway is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Felicia Edwards is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Kenneth Woods is in the checkout section is removed
# Customer Kimberly Gonzales is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jennifer Morgan is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Natalie Gould is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jose Reyes is in the checkout section is removed
# Customer April Bates is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Brady Gamble is in the checkout section is removed
# Customer Brett Silva is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Melissa Jones is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Zachary Beck is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer David Hughes is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Cassandra Baker is in the checkout section is removed
# Customer Michael Kelley is in the checkout section is removed
# Customer Linda Martinez is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jim Gregory DVM is in the checkout section is removed
# Customer Johnny Ellis is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Rebecca Mays is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Ryan Scott is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Cynthia Morrison is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Ashley Watson is in the checkout section is removed
# Customer David Kerr is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Thomas Jordan is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Kayla Brown is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Emily Curtis is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Chloe Kim is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Joshua Gentry is in the checkout section is removed
# Customer Joshua Phillips is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Jessica Liu is in the checkout section is removed
# Customer Luis Mitchell is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jessica Smith is in the checkout section is removed
# Customer Melissa Costa MD is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer George Miller is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Melanie Smith is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Thomas Obrien is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Annette Frank is in the checkout section is removed
# Customer Robert Larson is in the checkout section is removed
# change_state
# change_state
# Customer Evan Smith is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Shannon Sanders is in the checkout section is removed
# Customer Allen Levy is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Anthony Johnson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Teresa Pace is in the checkout section is removed
# Customer Mr. Thomas Powers is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Glenn Reynolds is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Darius Johnson is in the checkout section is removed
# Customer Leslie Harper is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Ashlee Rivers is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Brad Howard is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Lisa Eaton is in the checkout section is removed
# Customer Luis Woods is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jerry Orr is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Dennis Jones is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Brandon Jones is in the checkout section is removed
# Customer Katherine Howard is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Stephanie Perry is in the checkout section is removed
# Customer Gina Adams is in the checkout section is removed
# Customer Glenn Pearson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Dylan Glenn is in the checkout section is removed
# Customer Gabriel Johns is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Sydney Martin is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Erika Briggs is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Betty Zavala is in the checkout section is removed
# Customer Dennis Morrow is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Daniel Miller is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Jimmy Harrison is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Randy Heath is in the checkout section is removed
# Customer Jade Smith is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Doris Fleming is in the checkout section is removed
# Customer Ethan Nicholson is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Kimberly Spencer is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Nicholas Bryant is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Christopher Smith is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Dr. Amanda Murray is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Mason Atkins is in the checkout section is removed
# Customer Douglas Oliver is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Kevin Ramsey is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Lori Montgomery is in the checkout section is removed
# Customer Wesley Mayer is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Victoria Glenn is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Jermaine Lawrence is in the checkout section is removed
# Customer Toni Sullivan is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Denise Henry is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Laura Bowman is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Thomas Guzman is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Ashley Gomez is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Adrienne Owens is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Fred Mosley is in the checkout section is removed
# Customer Margaret Evans is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer David Hernandez is in the checkout section is removed
# Customer Daniel Anderson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Alexander Howard is in the checkout section is removed
# Customer Barry Stone is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Cynthia Sampson is in the checkout section is removed
# Customer Joshua Erickson is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Brenda Flynn is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Michelle Martinez is in the checkout section is removed
# Customer Brenda Patterson is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Michael Peterson is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Joel Smith is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Michael Rodriguez is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Tyler Sanchez is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Joseph Jordan is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Doris Cook is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Robert Cunningham is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Cheryl Owens is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Doris Whitney is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Ashley Smith is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Elaine Williams is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Jennifer Mckee is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Frank Riley is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Nancy Taylor is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Travis Carlson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Samantha Olson is in the checkout section is removed
# Customer Kyle Young is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Erin Alvarez is in the checkout section is removed
# Customer Angelica Hill is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Patricia Vincent is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Michelle Roman is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Justin Newman is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Mark Stokes is in the checkout section is removed
# Customer Shane Lopez is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Megan Collins is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Zachary Bailey is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Derrick Singleton is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Derrick Garcia is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Melissa Cuevas PhD is in the checkout section is removed
# Customer Lori James is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Mary Chavez is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Christine Armstrong is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Victor Salas is in the checkout section is removed
# Customer Nicole Stevenson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Kayla Pope is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Sarah King is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jacob Jackson is in the checkout section is removed
# Customer Alexandra Sullivan is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Betty Benson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Amy Gray is in the checkout section is removed
# Customer Michelle Romero is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Donna Klein is in the checkout section is removed
# Customer Belinda Davis is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Sara Wright is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Brian Smith MD is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Eric Wagner is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Phillip Clark is in the checkout section is removed
# Customer Dawn Lawson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Shawn Hopkins is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Katherine Rivera is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Christopher Arnold is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer David Rose is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Mariah Lowery is in the checkout section is removed
# Customer Alexis Wilkins is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Rachel Lynch MD is in the checkout section is removed
# Customer Charles Gibbs is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Michael Davis is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jeffrey Hunt is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Laura Wilson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Daniel Baker is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Dale Lawson is in the checkout section is removed
# Customer Brian Aguirre is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Valerie Reed is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer April Trujillo is in the checkout section is removed
# Customer Andre Phillips is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Katrina Jones is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Valerie Cook is in the checkout section is removed
# Customer Julia Gray is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Andrea Jones is in the checkout section is removed
# Customer Sarah Morgan is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Tina Nguyen is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Gary Parrish is in the checkout section is removed
# Customer Austin Le is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Deborah Moody is in the checkout section is removed
# Customer Troy Porter is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Janice Henderson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Teresa Bishop is in the checkout section is removed
# Customer Molly Clayton is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Vanessa Mcmillan is in the checkout section is removed
# Customer Brandon Wells is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Savannah Schultz is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Deanna Snyder is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Danielle Owens is in the checkout section is removed
# Customer Amber Waters is in the checkout section is removed
# change_state
# change_state
# Customer Brandon Acosta is in the checkout section is removed
# change_state
# change_state
# Customer David Conner is in the checkout section is removed
# change_state
# change_state
# Customer Eric Young is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Daniel Edwards is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Shannon Williams is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Paul Cherry is in the checkout section is removed
# Customer Christina Baxter is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Erin Odonnell is in the checkout section is removed
# Customer Blake Porter is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Joy Gonzalez is in the checkout section is removed
# Customer Tammy Richard is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Karen Miller is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jeffrey Carter is in the checkout section is removed
# Customer Kyle Campbell is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Kayla Hodges is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Karla Garrison is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Nicole Dyer is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Jesus Evans is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Carol Foster is in the checkout section is removed
# Customer Ann Clark is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer John Simmons is in the checkout section is removed
# Customer Jesse Neal is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Ryan Jones is in the checkout section is removed
# Customer Kelly Wong is in the checkout section is removed
# change_state
# change_state
# Customer Mark Jensen is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Bryan Powers is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Jessica Cook is in the checkout section is removed
# Customer Thomas Hunter is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Rodney Schwartz is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Joshua Brown is in the checkout section is removed
# Customer Andrew Mccann is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Marie Wilkins is in the checkout section is removed
# Customer James Simpson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Peter Taylor is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Jacob Davenport is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Rebecca Woodard is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Erin Leonard is in the checkout section is removed
# Customer Sue Huffman is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Alisha Mason is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Mrs. Hayley Morgan is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Mrs. Brittany Jones is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Robert Lewis is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Timothy Ross is in the checkout section is removed
# Customer Stephen Evans is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Ricky Sullivan is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Patricia Richards is in the checkout section is removed
# Customer Bridget Mendoza is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Jessica Herring is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Deborah Villanueva is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Shelly Moore is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Susan Taylor is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Rose Brown is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Patricia Curtis is in the checkout section is removed
# Customer Christina Alexander is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Gloria Kennedy is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Brandon Johnson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Julie Reed is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Amber Spencer is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Brenda Wolf is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Amy Garcia is in the checkout section is removed
# Customer Jennifer Black MD is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Christopher Graves is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Mitchell Lambert is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Vincent Molina is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Erica Thomas is in the checkout section is removed
# Customer Hunter Macias is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Deanna Mendoza is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Andrew Brown is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Eric Davis is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Wendy Welch is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Edward Stokes is in the checkout section is removed
# Customer Nicole Roberts is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Marissa Santana is in the checkout section is removed
# Customer Mark Alexander is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Kimberly Jones is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Nancy Mitchell is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Adam Washington is in the checkout section is removed
# Customer Dr. John Gonzalez is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Cory Ward is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Dustin Parsons is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Megan Myers is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Hannah Bates is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Miss Janet Ayala is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Natalie Brown is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Joanna Diaz is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jennifer Saunders is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Anna Boyd is in the checkout section is removed
# Customer Kristopher Brown is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Rachel Jennings is in the checkout section is removed
# Customer Daniel Martinez is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Danielle Cole is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jane Sanders is in the checkout section is removed
# Customer David May is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Tara Campos is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Faith Reed is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Emma Lowe is in the checkout section is removed
# ...
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Amanda Harris is in the checkout section is removed
# Customer Daniel Whitaker is in the checkout section is removed
# Customer Keith Rivas is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Joanna Peters is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jerry Baxter is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Miranda Burns is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jeffrey Martinez is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Donald Munoz is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Austin Williams is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jack Vargas is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Michael Lee is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Alan Price is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Alicia Waller is in the checkout section is removed
# Customer Kimberly George is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jenna Williams is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Megan Nguyen is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Kimberly Thompson is in the checkout section is removed
# Customer Jeremy Morrison is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Shelley Rodriguez is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Melissa Martinez is in the checkout section is removed
# Customer Louis Cobb is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Carolyn Leach is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Austin Thomas is in the checkout section is removed
# Customer Thomas Brown is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Sheila Spears is in the checkout section is removed
# Customer Kevin Reynolds is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Steven Benjamin is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jeffrey Carpenter is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Ashley Wright is in the checkout section is removed
# Customer Sara Robinson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Noah Brooks is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Sherry Pierce is in the checkout section is removed
# Customer Michael Jones is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Hector Foster is in the checkout section is removed
# Customer Bethany Watson is in the checkout section is removed
# Customer Mary Hubbard is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Mark Smith is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Stephen Pacheco is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Christina Noble is in the checkout section is removed
# Customer Carlos Palmer is in the checkout section is removed
# Customer Tyler Fitzgerald is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Joseph Rodriguez is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Matthew Rogers is in the checkout section is removed
# Customer Ann George is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Courtney Miranda is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Robert Moreno is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Mrs. Amber Hendricks is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer John Estrada is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Oscar Schaefer is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Justin Johnson is in the checkout section is removed
# Customer Marissa Tapia is in the checkout section is removed
# change_state
# change_state
# Customer Glenn Hayes is in the checkout section is removed
# change_state
# change_state
# Customer Carla Hernandez is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer James Greer is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Lawrence Cunningham is in the checkout section is removed
# Customer Joseph Garcia is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Kenneth Vaughn is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Danielle Smith is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Jordan Simpson is in the checkout section is removed
# Customer Karen Munoz is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Mary Nash is in the checkout section is removed
# Customer Cynthia Cannon is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Angela Harper is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Jessica James is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Antonio Smith is in the checkout section is removed
# Customer William Morgan is in the checkout section is removed
# Customer Fernando Weeks is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Dr. Logan Clark is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Nathan Walters is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Stephanie Salazar is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Kurt Palmer is in the checkout section is removed
# Customer Robert Williams is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Haley Garcia is in the checkout section is removed
# Customer Tina Lozano is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Diane Cowan is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Matthew Robinson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Kaylee Johnson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Todd Lin is in the checkout section is removed
# Customer Drew Patel is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Dawn Taylor is in the checkout section is removed
# Customer Michael Brown is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Alicia Little is in the checkout section is removed
# Customer Anna Lewis is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer David Baldwin is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Ashley Casey is in the checkout section is removed
# Customer Nathan Hunt is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Nicole Warren is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Matthew Lewis is in the checkout section is removed
# Customer Christine Martin is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Jeffrey Miller is in the checkout section is removed
# Customer Jeffrey Mahoney is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Brandon Randall is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Kenneth Roberts is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Joseph Lowe is in the checkout section is removed
# Customer Matthew Sexton is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Zachary Murphy is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer James Huerta is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer William Mitchell is in the checkout section is removed
# Customer Brenda Cortez is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Michael Galvan is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Robert Cameron is in the checkout section is removed
# Customer Katie Newman is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Katherine Wong is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Jaime Owens is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Hannah Mckay is in the checkout section is removed
# Customer Joseph Drake is in the checkout section is removed
# Customer Mark Cunningham is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Michael Watkins is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Rachel Fields is in the checkout section is removed
# Customer Sarah Gomez is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Jonathan Delacruz is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Douglas Thompson is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Sherry Estrada is in the checkout section is removed
# change_state
# change_state
# change_state
# Customer Amber Mcgee is in the checkout section is removed
# Customer Nancy Tran is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Joshua Stone is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer James Ortiz is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Travis Gomez is in the checkout section is removed
# Customer Anthony Harrington is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Kathryn Williams is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Blake Banks is in the checkout section is removed
# Customer Jennifer Ball is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Sydney Rodriguez is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Matthew Cox is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Stacy Taylor is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Patricia Harmon is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Erika Mills is in the checkout section is removed
# Customer Darrell Parker is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Helen Long is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Daniel Johnson is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# Customer Vincent Mullins is in the checkout section is removed
# Customer Andrew Molina is in the checkout section is removed
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# change_state
# Customer Alyssa Rodriguez is in the checkout section is removed
