# %%
import pandas as pd 
import numpy as np

# %%
transition_matrix = transition_matrix = pd.read_csv("data/trans_matrix_prob.csv")
transition_matrix.set_index('location', inplace = True)
#transition_matrix.drop('Unnamed: 0', axis=1, inplace=True)
print(transition_matrix)
# Out:
#           checkout     dairy    drinks     fruit    spices
# location
# checkout  0.999121  0.000216  0.000248  0.000303  0.000111
# dairy     0.061823  0.864568  0.003069  0.035356  0.035183
# drinks    0.116492  0.107547  0.598705  0.071664  0.105593
# fruit     0.104721  0.033201  0.031932  0.808821  0.021325
# spices    0.100893  0.068914  0.063509  0.048495  0.718189

# %%
# check the matrix sum(sum each row) == 5 ---> ok!
sum(transition_matrix.sum(axis=1))
# Out:
# 5.0

# %%
# to select row of transition matrix: transition_matrix.iloc[i,:]
transition_matrix.iloc[0,:]
# Out:
# checkout    0.999121
# dairy       0.000216
# drinks      0.000248
# fruit       0.000303
# spices      0.000111
# Name: checkout, dtype: float64

# %%
# define state
#state = ['checkout', 'dairy', 'drinks', 'fruit', 'spices']

# %%
# define transition name: possible sequence of events
#transition_name = [['CkCk', 'CkDa', 'CkDr', 'CkFr', 'CkSp' ],
                  # ['DaCk', 'DaDa', 'DaDr', 'DaFr', 'DaSp' ],
                   #['DrCk', 'DrDa', 'DrDr', 'DrFr', 'DrSp' ],
                 #  ['FrCk', 'FrDa', 'FrDr', 'FrFr', 'FrSp' ],
                  # ['SpCk', 'SpDa', 'SpDr', 'SpFr', 'SpSp' ]]

# %%
import numpy as np



class Customer:
    """Customer class for Supermarket simulation"""
    
    def __init__(self, customer_no, state, transition_matrix):
        self.customer_no = customer_no
        self.state = state
        self.transition_matrix = transition_matrix    # transition matrix
        
        
    def __repr__(self):
        return f'Customer {self.customer_no} is in the {self.state} section'
         
   
    
    
    
    def change_state(self):
            
            #print(self.state)
            print('Customer is moving to another section')
               
            self.state = np.random.choice(self.transition_matrix.columns.values, p=self.transition_matrix.loc[self.state]) #, replace=False)
            
   # random.choices

# %% [markdown]
# ## simulation for 1 customer

# %%
c1 = Customer(1, 'drinks', transition_matrix)

# %%
c1.state
# Out:
# 'drinks'

# %%
c1.change_state()
# Out:
# Customer is moving to another section

# %%
c1.state
# Out:
# 'checkout'

# %%
customers = [Customer(i, 'fruit',transition_matrix) for i in range(10)]

# %%
for i, c in enumerate(customers): #at each minute, move all customers
    c.change_state()
    if c.state == 'checkout':
        print(f'Customer {i} has been churned!')
# Out:
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section

# %%
customers
# Out:
# [Customer 0 is in the fruit section,
#  Customer 1 is in the fruit section,
#  Customer 2 is in the fruit section,
#  Customer 3 is in the fruit section,
#  Customer 4 is in the fruit section,
#  Customer 5 is in the fruit section,
#  Customer 6 is in the fruit section,
#  Customer 7 is in the fruit section,
#  Customer 8 is in the fruit section,
#  Customer 9 is in the fruit section]

# %% [markdown]
# ## create class Supermarket

# %%
import time
import datetime
from faker import Faker



fake = Faker()
open_supermarket = datetime.datetime(year= 2021, month=1, day=1,hour=7, minute=0)
close_supermarket = datetime.datetime(year= 2021, month=1, day=1,hour=21, minute=0)


class Supermarket:
    """manages multiple Customer instances that are currently in the market.
 """

    def __init__(self, customers): 
        self.customers = customers
        self.current_time = 0 
        

    def get_time(self):  #open supermarket
        """opening hour
        """
  
        
        self.current_time = open_supermarket  # opening hour
      
        return self.current_time
    
    def next_minute(self):
        """propagates all customers to the next state 
        w/ change_state
     """
        self.current_time = self.current_time + datetime.timedelta(minutes=1)
     
        
        for element in self.customers:
            element.change_state()
            
        return self.current_time   #?
    
    
    
    def remove_ex_customers(self):
        """remove churned from list"""
        
        for element in self.customers:
            if element.state == 'checkout':
                self.customers.remove(element)
                print(f'{element} and has checked out')
    
 
    def simulate(self):
        
   
        self.get_time()
        self.next_minute()
        
        
        while self.current_time > open_supermarket: 
                
                
                self.next_minute()
                self.remove_ex_customers()
                
                c = Customer(fake.name(), 'drinks', transition_matrix)
          
                self.customers.append(c)    # append more customers?
                   
                if self.current_time > close_supermarket:
                    
                    break

# %%
#import time
#import datetime
#open_supermarket = datetime.datetime(year= 2021, month=1, day=1,hour=7, minute=0)
#current_time = open_supermarket 
#current_time = current_time + datetime.timedelta(minutes=1)

# %%
#current_time > open_supermarket

# %%
customers = [Customer(i, 'fruit',transition_matrix) for i in range(100)]

# %%
s = Supermarket(customers)

# %%
s.simulate()
# Out:
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 3 is in the checkout section and has checked out
# Customer 12 is in the checkout section and has checked out
# Customer 17 is in the checkout section and has checked out
# Customer 27 is in the checkout section and has checked out
# Customer 29 is in the checkout section and has checked out
# Customer 32 is in the checkout section and has checked out
# Customer 40 is in the checkout section and has checked out
# Customer 44 is in the checkout section and has checked out
# Customer 46 is in the checkout section and has checked out
# Customer 50 is in the checkout section and has checked out
# Customer 53 is in the checkout section and has checked out
# Customer 66 is in the checkout section and has checked out
# Customer 77 is in the checkout section and has checked out
# Customer 82 is in the checkout section and has checked out
# Customer 90 is in the checkout section and has checked out
# Customer 96 is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 6 is in the checkout section and has checked out
# Customer 13 is in the checkout section and has checked out
# Customer 23 is in the checkout section and has checked out
# Customer 36 is in the checkout section and has checked out
# Customer 58 is in the checkout section and has checked out
# Customer 69 is in the checkout section and has checked out
# Customer 71 is in the checkout section and has checked out
# Customer 87 is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 1 is in the checkout section and has checked out
# Customer 7 is in the checkout section and has checked out
# Customer 35 is in the checkout section and has checked out
# Customer 55 is in the checkout section and has checked out
# Customer 73 is in the checkout section and has checked out
# Customer 76 is in the checkout section and has checked out
# Customer 81 is in the checkout section and has checked out
# Customer 92 is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 2 is in the checkout section and has checked out
# Customer 5 is in the checkout section and has checked out
# Customer 14 is in the checkout section and has checked out
# Customer 28 is in the checkout section and has checked out
# Customer 33 is in the checkout section and has checked out
# Customer 60 is in the checkout section and has checked out
# Customer 63 is in the checkout section and has checked out
# Customer 68 is in the checkout section and has checked out
# Customer 74 is in the checkout section and has checked out
# Customer 91 is in the checkout section and has checked out
# Customer Melissa Ochoa is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 4 is in the checkout section and has checked out
# Customer 16 is in the checkout section and has checked out
# Customer 24 is in the checkout section and has checked out
# Customer 45 is in the checkout section and has checked out
# Customer 65 is in the checkout section and has checked out
# Customer 85 is in the checkout section and has checked out
# Customer 88 is in the checkout section and has checked out
# Customer 97 is in the checkout section and has checked out
# Customer Catherine Lopez is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 26 is in the checkout section and has checked out
# Customer 52 is in the checkout section and has checked out
# Customer 83 is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 10 is in the checkout section and has checked out
# Customer 15 is in the checkout section and has checked out
# Customer 38 is in the checkout section and has checked out
# Customer 42 is in the checkout section and has checked out
# Customer 70 is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 0 is in the checkout section and has checked out
# Customer 34 is in the checkout section and has checked out
# Customer 49 is in the checkout section and has checked out
# Customer 56 is in the checkout section and has checked out
# Customer 80 is in the checkout section and has checked out
# Customer 94 is in the checkout section and has checked out
# Customer Curtis Adams is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 25 is in the checkout section and has checked out
# Customer 75 is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 8 is in the checkout section and has checked out
# Customer 21 is in the checkout section and has checked out
# Customer 37 is in the checkout section and has checked out
# Customer 79 is in the checkout section and has checked out
# Customer Michelle Smith is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 20 is in the checkout section and has checked out
# Customer 30 is in the checkout section and has checked out
# Customer 39 is in the checkout section and has checked out
# Customer 61 is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 19 is in the checkout section and has checked out
# Customer 51 is in the checkout section and has checked out
# Customer Carolyn Huber is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 54 is in the checkout section and has checked out
# Customer 95 is in the checkout section and has checked out
# Customer Jacob Perez is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 43 is in the checkout section and has checked out
# Customer 57 is in the checkout section and has checked out
# Customer 89 is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 11 is in the checkout section and has checked out
# Customer 31 is in the checkout section and has checked out
# Customer Doris Flores is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Bethany Jones is in the checkout section and has checked out
# Customer Gwendolyn Mathis is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 41 is in the checkout section and has checked out
# Customer 62 is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 93 is in the checkout section and has checked out
# Customer John Carney is in the checkout section and has checked out
# Customer Jamie Dorsey is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 99 is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 18 is in the checkout section and has checked out
# Customer Robert Lawson is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 22 is in the checkout section and has checked out
# Customer 86 is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 47 is in the checkout section and has checked out
# Customer 72 is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Christopher Martinez is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 9 is in the checkout section and has checked out
# Customer 59 is in the checkout section and has checked out
# Customer Julia Rubio is in the checkout section and has checked out
# Customer Seth Farley is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer 48 is in the checkout section and has checked out
# Customer is moving to another section
# ...
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Jonathan Livingston is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Jorge Harvey is in the checkout section and has checked out
# Customer Connie Montoya is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Kristin Barber is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Richard Webster is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Judith Baker is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Jason Rodriguez is in the checkout section and has checked out
# Customer Ricky Silva is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Alicia Paul is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Sherry Crawford is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Holly Taylor is in the checkout section and has checked out
# Customer Dawn Aguilar is in the checkout section and has checked out
# Customer Mark Bailey is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Gene Logan is in the checkout section and has checked out
# Customer Terrence Green is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Anna Luna is in the checkout section and has checked out
# Customer Rhonda Roberts is in the checkout section and has checked out
# Customer Dennis Flores is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer John Brown is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Sara Holt is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Wanda Stanley is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Evan Williams is in the checkout section and has checked out
# Customer Angela Oliver is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Connor Simmons is in the checkout section and has checked out
# Customer Nancy Ortiz is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Bruce Gonzalez is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Randy Robbins is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Christine Owen is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Susan Callahan is in the checkout section and has checked out
# Customer Alyssa Jackson is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Fred Owen is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Brian Johnson is in the checkout section and has checked out
# Customer Victoria Obrien is in the checkout section and has checked out
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer is moving to another section
# Customer Kristen Davis is in the checkout section and has checked out
